# %% [markdown]
# # <span style="color:darkblue"> Lecture 7: User-defined Functions </span>

# %%
# define functions
# lambda functions
# visualize functions

# %% [markdown]
# ## <span style="color:darkblue"> I. Import Libraries </span>

# %%
# the "numPy" library is used for mathematical operations
# the "matplotlib" library is for generating graphs
# the "pandas" library is for manipualting datasets

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## <span style="color:darkblue"> II. Introduction to Functions </span>

# %% [markdown]
# <font size="5">
#
# A function is ...
#
# - a **block of reusable** code to perform a a specific task
# - Functions avoid repetition
# - As our code grows larger, functions make it more manageable

# %% [markdown]
# <font size="5">
#
# "Built-in" functions are those from Python libraries, e.g.
#
# ```print()```, ```type()```, ```round()```,```abs()```, ```len()```
#
# - The "arguments" are the values of the inputs
# - The "return" is the output

# %%
# Argument:   "Hello" 
# Return:     Showing the message on screen

print("Hello "+str(24))
# Out:
# Hello 24

# %%
# Argument:  3.14
# Return:    The type of object, e.g. int, str, boolean, float, etc.

type(3.14)
# Out:
# float

# %%
# First Argument:   np.pi     (a numeric value)
# Second Argument:  6         (the number of decimals)
# Return:  Round the first argument, given the number of decimals in the second argument

round(np.pi,  6)
# Out:
# 3.142

# %%
round(3.1415926535, 3)
# Out:
# 3.142

# %%
# Argument: -4
# Return:   The absolute value
abs(-10)
# Out:
# 10

# %%
list_fruits = ["Apple","Orange","Pear"]

# Argument: list_fruits
# Return:   The number of elements in the list
len(list_fruits)
# Out:
# 3

# %%
len('Hello')
# Out:
# 5

# %% [markdown]
# <font size = "5">
#
# Enter arguments by assigning parameters

# %%
# Here "df" and "size" are both parameters
# They get assigned the arguments "2" and "20", respectively
# The return is a vector of random variables

#  vec_chisqr  = np.random.chisquare(df = 1, size = n)
vec_x = np.random.chisquare(df = 2, size = 20)

# %%
# The return is a vector of random variables
vec_x
# Out:
# array([0.08349536, 1.92753481, 0.47142061, 6.46865493, 0.65149751,
#        6.00930812, 0.51146313, 2.81067495, 0.86685348, 2.78875585,
#        1.16867447, 1.37353811, 0.83951537, 1.63166919, 0.34235188,
#        3.16410751, 1.98392104, 4.87125857, 0.44866347, 0.61595858])

# %%
vec_y = np.random.normal(loc = 2, scale = 1, size = 20)
vec_z = np.random.uniform(low = -2, high =2, size = 50)

# %%
vec_y
# Out:
# array([ 1.71439652,  2.78414061,  1.9666169 , -0.43446441,  1.51351579,
#         3.54776841,  2.03849801,  0.83221096,  1.24806767,  2.75537913,
#         2.41901409,  3.65594619,  1.3275376 ,  2.13880345,  2.78349315,
#         1.19816577,  2.24915937,  0.98202154,  1.48581672,  0.92571337])

# %% [markdown]
# <font size = "5">
#
# Discussion:
#
# - What are the parameters, arguments, and returns above?

# %% [markdown]
# ## <span style="color:darkblue"> III. Custom Functions </span>

# %% [markdown]
# <font size = "5">
#
# You can write your own functions:
#
# ```python
#
#     #---- DEFINE
#     def my_function(parameter):
#         body
#         return expression
#
#     #---- RUN
#     my_function(parameter = argument)
#
#     #---- RUN
#     my_function(argument)
# ```
# <br>

# %% [markdown]
# <font size = "5">
#
# Example: Calculate
#
# $V=P\left(1+{\frac {r}{n}}\right)^{nt}$

# %%
# We are going to define a function "fn_compute_value"
# You can choose any name
# Using prefixes like "fn_" can help you remember this is a "function" object
# What are the parameters?

def function_v(P, r,n, t):
    v = P*(1+(r/n))**(n*t)
    return v

# %%
function_v(P=100, r = 0.01, n = 20, t=10)
# Out:
# 110.51432983541218

# %%
# You can know compute the formula with different values

V1 = function_v(P = 1000, r = 0.01, n = 20, t=10)
V2 = function_v(P = 10, r = 0.01, n = 20, t=10)

print(V1)
print(V2)
# Out:
# 1105.1432983541217
# 11.051432983541218

# %% [markdown]
# <font size = "5">
#
# Try it yourself:
#
# - Write a function that calculates <br>
#  $f(x,y) = y+ x^2 + 2x + 1$.

# %%
# Write your own code here

def function_v(x,y):
    v = y + x**2 + 2*x +1
    return v

M1 = function_v(x=1,y=2)

print(M1)
# Out:
# 6

# %% [markdown]
# <font size = "5">
#
# Try it yourself: Write a function
#
# - with a parameter "numeric_grade"
# - Inside the function write an <br>
# if/else statement for grade $\ge 55$.
# - If it's true, then assign "status = pass"
# - If it's false, then assign "status = fail"
# - Return the value of "status"

# %%
# Write your own code

def myfunction(numeric_grade):
    if numeric_grade >= 55:
        message = "status = pass"
    else:
        message = "status = fail"
    return message

myfunction(93)
# Out:
# 'status = pass'

# %% [markdown]
# <font size = "5">
#
# Try it yourself! Write a function
# - Write a function with parameters <br>
#  "first_name", "last_name", "car_model"
# - Return a message saying:
#
# "Dear customer {first_name} {last_name}, <br>
# your car model {car_model} is ready"

# %%
# Write your own code
# The + sign concatenates those strings and variable values into one continuous string.
def carorder(first_name,last_name,car_model):
    return "Dear customer " + first_name + " " + last_name + ", your car model " + car_model + " is ready"

carorder("Alejandro", "Sanchez","KIA")
# Out:
# 'Dear customer Monica Zheng, your car model Car is ready'

# %% [markdown]
# ## <span style="color:darkblue"> III. Lambda Functions </span>
#
# <font size = "5">
#
# "Lambda Functions" are defined in one line:
#
# ```python
# my_function = lambda parameters: expression
# ```

# %% [markdown]
# <font size = "5">
#
# Example: Calculate $x + y + z$

# %%
# (a) Define function
fn_sum = lambda x,y,z: x + y + z

# (b) Run function
fn_sum(1,2,3)
# Out:
# 6

# %%
fn_random = lambda x,y: y**x 
fn_random(1,2)
# Out:
# 2

# %% [markdown]
# <font size = "5"> Example: Calculate
#
# $V=P\left(1+{\frac {r}{n}}\right)^{nt}$

# %%
fn_v = lambda P, r, n, t: P*(1+(r/n))**(n*t)

# %%
V1 = fn_v(P = 1000, r = 0.01, n = 20, t=10)
V2 = fn_v(P = 10, r = 0.01, n = 20, t=10)

print(V1)
print(V2)
# Out:
# 1105.1432983541217
# 11.051432983541218

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# (a) Boleean + Functions
#
# - Write a function called "fn_iseligible_vote"
# - This functions returns a boolean value <br>
#  that checks whether age $\ge$ 18

# %%
# Write your own code

def fn_iseligible_vote(Age):
    if Age >= 18:
        message = "True"
    else:
        message = "False"
    return message

fn_iseligible_vote(20)
# Out:
# 'True'

# %% [markdown]
# <font size = "5">
#
# (b) Looping  + Functions
#
# - Create list_ages = [18,29,15,32,6]
# - Write a loop that checks whether above ages are eligible to vote
# - Use the above function

# %%
# Write your own code
def fn_iseligible_vote(Age):
    if Age >= 18:
        message = "True"
    else:
        message = "False"
    return message

list_ages = [18,29,15,32,6]

for age in list_ages:
    print("Age " + str(age) + " is eligible? " + str(fn_iseligible_vote(age)))
# Out:
# Age 18 is eligible? True
# Age 29 is eligible? True
# Age 15 is eligible? False
# Age 32 is eligible? True
# Age 6 is eligible? False

# %% [markdown]
# ## <span style="color:darkblue"> IV. (Optional) Functions for visualization </span>
#
# <font size = "5">
# Returning a value is not always necesary, you can write:
#
# ```python
#
#     #---- DEFINE
#     def my_function(parameter):
#         body
# ```

# %% [markdown]
# <font size = "5">
#
# Example: A customized plot
#
# - You can use functions to store your favorite aesthetic

# %%
# Define the function
def red_histogram(vec_x,title):
    plt.hist(x = vec_x, color = "red")
    plt.title(title)
    plt.ylabel("Frequency")
    plt.show()

carfeatures = pd.read_csv("data/features.csv")

red_histogram(vec_x = carfeatures["weight"], title = "Histogram")
red_histogram(vec_x = carfeatures["acceleration"], title = "Histogram")

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# Create a function that computes a red scatter plot <br>
#  that takes $y$ and $x$ inputs

# %%
# Write your own code
# Define the function

red_scatterplot = lambda x,y: x + y

def red_scatterplot(X,Y):
    plt.scatter(x = X, y = Y)
    plt.xlabel("X Value")
    plt.ylabel("Y Value")
    plt.show()

list_x = [1,2,3,4,5,6,7,8]
list_y = [1,2,3,4,5,6,7,8]

red_scatterplot(list_x,list_y)

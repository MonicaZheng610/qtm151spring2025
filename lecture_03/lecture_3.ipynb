# %% [markdown]
# # <span style="color:darkblue"> Lecture 3: Mathematical Operations and Random Numbers </span>

# %% [markdown]
# <font size="5">
#
# In the previous class we:
# - Introduced lists and variable types
# - Talked about how to extract elements from a list

# %% [markdown]
# <font size="5">
#
# In this class we will:
#
# - Introduce a library for general mathematical operations
# - Generate random numbers
# - (Optional) Matrix operations

# %%
#1. np. math functions (in(x), sin(x)..)
#2. Vector Arrays
#3. Statistics function (mean/std/...)
#4. Vector of Random Numbers
#5. np.random.seed()
      #Avoid producing diff set of numbers
#6. Histogram with random set

# %% [markdown]
# ## <span style="color:darkblue"> I. Import Libraries </span>

# %%
# the "numPy" library is used for mathematical operations
# the "matplotlib" library is for generating graphs

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##  <span style="color:darkblue"> II. Numbers and Functions </span>

# %% [markdown]
# <font size = "5" >
# Examples of numPy numbers

# %%
# Computes "pi" (3.14...)

np.pi
# Out:
# 3.141592653589793

# %% [markdown]
# <font size = "5" >
#
# Examples of numPy functions
#
# $ ln(x), e^x, sin(x), cos(x), \sqrt{x}$

# %%
# log(x) computes the logarithm with base "e" (Euler constant)
# exp(x) compute the Euler constant raised to the power of "x"
# sing(x) computes the sine of x
# cos(x) computes the cosine of x
# In this example, we're substituting x = 1

print(np.log(1))
print(np.exp(1))
print(np.sin(1))
print(np.cos(1))
print(np.sqrt(1))
# Out:
# 0.0
# 2.718281828459045
# 0.8414709848078965
# 0.5403023058681398
# 1.0

# %% [markdown]
# <font size = "5">
#
# Raising to the power of a number
#
# $ x^5 $

# %%
x = 10
x ** 5

# Not x^5
# Out:
# 100000

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# - Create a new variable, $x = 5$
# - Compute $\pi x^2$
# - Compute $ \frac{1}{\sqrt{2\pi}}e^{-x^2} $

# %%
# Write your own code

x=5

#compute pix^2
print(np.pi*x**2)
np.pi*(x**2)

print((np.exp(-x**2))/(np.sqrt(2*np.pi)))
# Out:
# 78.53981633974483
# 5.540487995575833e-12

# %% [markdown]
# ##  <span style="color:darkblue"> III. Vector Arrays </span>

# %% [markdown]
# <font size = "5">
# Create an array from a list
#
# $ \text{ }$
# $ a = \begin{pmatrix} 1 \\ 2 \\ 3 \end{pmatrix}
# \qquad b = \begin{pmatrix} 0 \\ 1 \\ 0\end{pmatrix}
# \qquad c = \begin{pmatrix} 10 \\ 100 \\ 1000 \\ 2000 \\ 5000 \end{pmatrix}
# \qquad d = \begin{pmatrix} 4 \\ 2 \end{pmatrix} $

# %%
# You create an array by converting a list [1,2,3] to a numeric object
# "array" is a subfunction of the library numPy.

vec_a  = np.array([1,2,3])
vec_b  = np.array([0,1,0])
vec_c  = np.array([10,100,1000,2000,5000 ])
vec_d  = np.array([4,2])
# Out:
# [1 2 3]

# %% [markdown]
# <font size = "5">
#
# Accessing an element of an array

# %%
# Arrays, like lists, start their numbering at zero.
# You also access them with square brackets

print(vec_a[0])
print(vec_a[2])
print(vec_c[3])
print(vec_d[1])
# Out:
# 1
# 3
# 2000
# 2

# %% [markdown]
# <font size = "5">
# Operations with a single array and a scalar

# %% [markdown]
# <font size = "5">
#
# $ a + 2 = \begin{pmatrix} a_1 + 2 \\ a_2 + 2 \\ a_3 + 2 \end{pmatrix}$

# %%
# A scalar refers to either an int or float
# We can do many common operations with 

print(vec_a * 2)
print(vec_a / 2)
print(vec_a + 2)
print(vec_a ** 2)
# Out:
# [2 4 6]
# [0.5 1.  1.5]
# [3 4 5]
# [1 4 9]

# %% [markdown]
# <font size = "5">
# Element-by-element addition between two arrays of the same size
#
# $\text{ }$
#
# $ a + b = \begin{pmatrix} a_1 \\ a_2 \\ a_3 \end{pmatrix} +
#           \begin{pmatrix} b_1 \\ b_2 \\ b_3 \end{pmatrix} =
#           \begin{pmatrix} a_1 + b_1 \\ a_2 + b_2 \\ a_3 + b_3 \end{pmatrix}$

# %%
print(vec_a)
print(vec_b)
# Out:
# [1 2 3]
# [0 1 0]

# %%
# When you add two arrays of the same size,
# Python adds the individual elements in each position

print(vec_a + vec_b)
print(vec_a-vec_b)
print(vec_a*vec_b)
print(vec_a/vec_b)
# Out:
# [1 3 3]
# [1 1 3]
# [0 2 0]
# [inf  2. inf]
# /var/folders/jv/khr6hfpn1hl318t7_t0fdsdw0000gn/T/ipykernel_31786/3638710767.py:7: RuntimeWarning: divide by zero encountered in divide
#   print(vec_a/vec_b)

# %% [markdown]
# <font size ="5">
#
# The default multiplication option is element-by element:
#
# $ a * b = \begin{pmatrix} a_1 * b_1 \\ a_2 * b_2 \\ a_3 * b_3 \end{pmatrix}$

# %%
# We can do other similar element-by-element operations
# such as multiplication, subtraction, and division.

print(vec_a * vec_b)
print(vec_a - vec_b)
print(vec_a / vec_b)
# Out:
# [0 2 0]
# [1 1 3]
# [inf  2. inf]
# /var/folders/jv/khr6hfpn1hl318t7_t0fdsdw0000gn/T/ipykernel_31786/3839639845.py:6: RuntimeWarning: divide by zero encountered in divide
#   print(vec_a / vec_b)

# %% [markdown]
# <font size = "5">
# Summary statistics of an array

# %%
# The function np.mean() computes the mean of an array
# We can do similar operations for the standard deviation (std),
# the minimum (min), the median (median), and the maximum (max).
print(vec_a)
print(np.mean(vec_a))
print(np.std(vec_a))
print(np.min(vec_a))
print(np.median(vec_a))
print(np.max(vec_a))
# Out:
# [1 2 3]
# 2.0
# 0.816496580927726
# 1
# 2.0
# 3

# %% [markdown]
# <font size = "5">
#
# Try it yourself! Compute the mean of
#
#
# $ e = \begin{pmatrix} 10 \\ 8 \\ 15 \\ 0 \\ 24 \end{pmatrix} $

# %%
# Create your own array and compute any of the above summary statistics

e = np.array( [10,8,15,0,24] )

np.mean(e)
# Out:
# 11.4

# %% [markdown]
# <font size = "5">
# <span style="color:red"> Common Pitfall </span>: Make sure that the arrays have the same size

# %%
print(vec_a)
print(vec_c)
# Out:
# [1 2 3]
# [  10  100 1000 2000 5000]

# %%
vec_a.shape
# Out:
# (3,)

# %%
# Here I try to combine two arrays of different size.

vec_a + vec_c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Here I try to combine two arrays of different size.
# ----> 3 vec_a + vec_c
#
# ValueError: operands could not be broadcast together with shapes (3,) (5,)

# %% [markdown]
# ##  <span style="color:darkblue"> IV. Random Numbers </span>
#
# <font size = "5">
#
# Why randomness?
#
# - Simulate different scenarios: high risk or low risk
# - Study properties of a complex system and/or estimator
# - In medicine, randomly assign subjects to treatment or control

# %% [markdown]
# <font size = "5">
#
# Create a vector of random variables

# %%
# This code creates a vector of random variables 
# generated from a normal distribution with
# mean "loc" (location) and standard deviation "scale"
# the number of distinct variabels is "size"

randomvar_a = np.random.normal(loc=0, scale=1, size=10)
print(randomvar_a)
# Out:
# [-0.44174198  0.68001728 -0.00756101 -1.16641086 -0.71005411 -0.60502173
#  -1.09374714 -1.51940798  0.10734277  0.54731299]

# %% [markdown]
# <font size = "5">
#
# Random numbers differ every time!
#
# - Avoid this problem by drawing from a "pregenerated" set.
# - This is called a seed

# %%
# Your computer will typically generate different numbers every time you run a command
# However, sometimes you want to be able to replicate the results
# You can choose any other number instead of "12345". This will produce another set
# of random numbers, but they will give the same answers

np.random.seed(103931)

random_var_b = np.random.normal(loc=0, scale=1, size=10)
print(random_var_b)
# Out:
# [-0.33101264 -0.438638   -0.75090825 -0.36108372  0.46834289 -0.11326744
#  -0.04432165 -2.45982754  1.77349369  1.09337644]

# %% [markdown]
# <font size = "5">
#
# Compute a histogram with the results

# %%
# Compute a histogram
# You can edit the number of bins with plt.hist(x = randomvar_a)

randomvar_x = np.random.normal(loc=0, scale=1, size=1000)
# loc = mean; scale = standard dv 

plt.hist(x = randomvar_x)
plt.xlabel("Variable a")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# <font size = "5">
#
# Try this again with $size = 100, 1000, 10000$

# %%
# Write the code for your histogram

# Compute a histogram
# You can edit the number of bins with plt.hist(x = randomvar_a)

random_var_c = np.random.normal(loc=0, scale=1, size=1000000000)
print(random_var_c)

randomvar_x2= np.random.normal(loc=0, scale=1, size=1000000000)
print(randomvar_x2)

plt.hist(x = randomvar_x2)
plt.xlabel("Variable a")
plt.ylabel("Frequency")
# Out:
# [ 0.60451874 -0.52515091  1.02921116 ...  0.248221   -0.65253039
#  -2.4178033 ]
# [-0.40236838 -0.23056017 -0.44428582 ...  1.28913899  0.82352238
#  -1.17374073]
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # <span style="color:darkblue"> Additional Resources </span>
#
# <font size="5">
#
# Check out additional examples at:
#
# - https://allendowney.github.io/ElementsOfDataScience/03_arrays.html

# %% [markdown]
# <font size = "20">
#
# asdasd

# %% [markdown]
# # <span style="color:darkblue"> (Optional) Matrix Operations </span>
#
# <font size="5">

# %% [markdown]
# <font size = "5">
# Creating a matrix by stacking different rows
#
# $ \text{ }$
#
# $ X = \begin{pmatrix} 1 & 2 & 3 \\
#                        0 & 4 & 5 \\
#                        0 & 0 & 6
#                        \end{pmatrix} $

# %%
# Matrices are usually denoted by capital letters
# The object [[1,2,3],[4,5,6],[7,8,9]] is a list of lists
# It's useful to maintain this notation in the code as well

X = np.array([[1,2,3],[0,4,5],[0,0,6]])
print(X)
# Out:
# [[1 2 3]
#  [0 4 5]
#  [0 0 6]]

# %% [markdown]
# <font size = "5">
# Creating a matrix by stacking different columns
#
# $ \text{ } $
#
# $ Y = \begin{pmatrix} 1 & 2 \\ 0 & 1 \\ 1 & 0 \end{pmatrix}$

# %%
# You can also stack columns
Y =  np.column_stack([[1,0,1],[2,1,0]])
print(Y)

# %% [markdown]
# <font size = "5">
# Transpose
#
# $ \text{ }$
#
# $ Y' = \begin{pmatrix}  1 & 0 & 1 \\ 2 & 1 & 0  \end{pmatrix} $

# %%
# Matrix Transpose
np.matrix.transpose(Y)

# %% [markdown]
# <font size = "5">
#
# Matrix multiplication
#
# $ XY = \begin{pmatrix} 1 & 2 & 3 \\
#                        0 & 4 & 5 \\
#                        0 & 0 & 6
#                        \end{pmatrix}
#                        \begin{pmatrix} 1 & 2 \\ 0 & 1 \\ 1 & 0 \end{pmatrix} =
#         \begin{pmatrix} 4 & 4 \\ 5 & 4 \\ 6 & 0 \end{pmatrix} $

# %%
# Matrix Multiplication

np.dot(X,Y)

np.matmul(X,Y)

# %% [markdown]
# <font size = "5">
#
# Matrix inverse
#
# $ X^{-1} = \begin{pmatrix} 1 & 2 & 3 \\
#                        0 & 4 & 5 \\
#                        0 & 0 & 6
#                        \end{pmatrix}^{-1} $

# %%
# Check the determinant of a matrix (a matrix is invertible if the determinant is not zero)
print(np.linalg.det(X))

# Matrix inverse
# The following command stands for linear algebrar inverse.
X_inv = np.linalg.inv(X)

# Output the result
print(X_inv)

# %% [markdown]
# <font size = "5">
#
# Try it yourself! Check that this is indeed an inverse:
#
# $X X_{inv} = \begin{pmatrix} 1 & 0 & 0 \\ 0 & 1 & 0 \\ 0 & 0 & 1 \end{pmatrix}$

# %%
# Multiply "X" times "X_inv" using the command shown above
# Note: Sometimes the result is shown in scientific notation.
